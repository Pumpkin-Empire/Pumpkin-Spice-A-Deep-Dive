# %%
import sys
# !{sys.executable} -m pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2.tar.gz (220 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.8/220.8 kB 5.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.6.1 in /opt/homebrew/Cellar/jupyterlab/3.4.5/libexec/lib/python3.10/site-packages (from wordcloud) (1.23.2)
# Requirement already satisfied: pillow in /opt/homebrew/lib/python3.10/site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: matplotlib in /opt/homebrew/lib/python3.10/site-packages (from wordcloud) (3.5.3)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Cellar/jupyterlab/3.4.5/libexec/lib/python3.10/site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.37.1)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/homebrew/Cellar/jupyterlab/3.4.5/libexec/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Cellar/jupyterlab/3.4.5/libexec/lib/python3.10/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/six/1.16.0_2/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Building wheels for collected packages: wordcloud
#   Building wheel for wordcloud (setup.py) ... done
#   Created wheel for wordcloud: filename=wordcloud-1.8.2.2-cp310-cp310-macosx_12_0_arm64.whl size=154545 sha256=3357fedce2ca98b04195a0cff7a5a129777736b2b27c4ab346976c0cd0d4c0b6
#   Stored in directory: /Users/kendra/Library/Caches/pip/wheels/30/52/73/36458d38e3c533678a3043949ad72658025d8e89d942439d49
# Successfully built wordcloud
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2

# %%
import pandas as pd
import json

# %%
data = json.load(open('json.json'))

# %%
#first tweet data in entirety
data['data'][0]
# Out:
# {'entities': {'hashtags': [{'start': 131, 'end': 142, 'tag': 'amquerying'},
#    {'start': 143, 'end': 160, 'tag': 'WritingCommunity'},
#    {'start': 161, 'end': 178, 'tag': 'amwritingfiction'}],
#   'mentions': [{'start': 0,
#     'end': 14,
#     'username': 'AuthorJFuller',
#     'id': '448329810'}]},
#  'author_id': '1320819574317715463',
#  'text': '@AuthorJFuller Preparing to query and feeling anxious. Fortunately the local grocery is already stocking pumpkin spice everything. #amquerying #WritingCommunity #amwritingfiction',
#  'public_metrics': {'retweet_count': 0,
#   'reply_count': 0,
#   'like_count': 0,
#   'quote_count': 0},
#  'id': '1562107241460891649'}

# %%
#first user info - will need to use id: for primary/foreign key to relate to tweet
data['includes']['users'][0]
# Out:
# {'id': '1320819574317715463',
#  'username': 'KZimmerauthor',
#  'created_at': '2020-10-26T20:08:29.000Z',
#  'public_metrics': {'followers_count': 58,
#   'following_count': 138,
#   'tweet_count': 76,
#   'listed_count': 0},
#  'name': 'Kelly Zimmer',
#  'location': 'Florida USA'}

# %%
details = data['includes']['users']
testDF = pd.DataFrame(details)
testDF.head()
# Out:
#                     id         username                created_at  \
# 0  1320819574317715463    KZimmerauthor  2020-10-26T20:08:29.000Z
# 1   715742118589947904       picorimori  2016-04-01T03:26:33.000Z
# 2  1520531882886123520       FazeMadden  2022-04-30T22:33:57.000Z
# 3           2174166952  JonnyOlivares73  2013-11-09T06:57:07.000Z
# 4            172536397           AKyleW  2010-07-29T23:31:50.000Z
#
#                                       public_metrics           name  \
# 0  {'followers_count': 58, 'following_count': 138...   Kelly Zimmer
# 1  {'followers_count': 157, 'following_count': 13...          ning🐀
# 2  {'followers_count': 5, 'following_count': 70, ...  Nestor Toledo
# 3  {'followers_count': 405, 'following_count': 49...       Jonathan
# 4  {'followers_count': 161, 'following_count': 77...    Kyle Wagner
#
#          location
# 0     Florida USA
# 1             NaN
# 2             NaN
# 3  Framingham, MA
# 4   Bradenton, FL

# %%
for user in data['includes']:
    author_id = data['includes']['users'][0]['id']
    username = data['includes']['users'][0]['username']
    created_at = data['includes']['users'][0]['created_at']
    followers_count = data['includes']['users'][0]['public_metrics']['followers_count']
    name = data['includes']['users'][0]['name']
    location = data['includes']['users'][0]['location']
    
    remix = [author_id, username, created_at, followers_count, name, location]

# %%
print(remix)
# Out:
# ['1320819574317715463', 'KZimmerauthor', '2020-10-26T20:08:29.000Z', 58, 'Kelly Zimmer', 'Florida USA']

# %%
testDF.to_csv('test_csv_twitter.csv')

# %%
please_work = pd.read_csv('test_csv_twitter.csv')

# %%
please_work.head()
# Out:
#    Unnamed: 0                   id         username                created_at  \
# 0           0  1320819574317715463    KZimmerauthor  2020-10-26T20:08:29.000Z
# 1           1   715742118589947904       picorimori  2016-04-01T03:26:33.000Z
# 2           2  1520531882886123520       FazeMadden  2022-04-30T22:33:57.000Z
# 3           3           2174166952  JonnyOlivares73  2013-11-09T06:57:07.000Z
# 4           4            172536397           AKyleW  2010-07-29T23:31:50.000Z
#
#                                       public_metrics           name  \
# 0  {'followers_count': 58, 'following_count': 138...   Kelly Zimmer
# 1  {'followers_count': 157, 'following_count': 13...          ning🐀
# 2  {'followers_count': 5, 'following_count': 70, ...  Nestor Toledo
# 3  {'followers_count': 405, 'following_count': 49...       Jonathan
# 4  {'followers_count': 161, 'following_count': 77...    Kyle Wagner
#
#          location
# 0     Florida USA
# 1             NaN
# 2             NaN
# 3  Framingham, MA
# 4   Bradenton, FL

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import seaborn as sns
import re
import collections
from wordcloud import WordCloud

# %%
#Reading the raw data collected from the Twitter Streaming API using Tweepy. 
tweets_data = []
tweets_data_path = 'json.json'
tweets_file = open(tweets_data_path, "r")
for line in tweets_file:
    try:
        tweet = json.loads(line)
        tweets_data.append(tweet)
    except:
        continue

# %%
#Error codes from the Twitter API can be inside the .txt document, take them off
tweets_data = [x for x in tweets_data if not isinstance(x, int)]

# %%
print("The total number of Tweets is:",len(tweets_data))
# Out:
# The total number of Tweets is: 1

# %%
tweets_data
# Out:
# [{'data': [{'entities': {'hashtags': [{'start': 131,
#        'end': 142,
#        'tag': 'amquerying'},
#       {'start': 143, 'end': 160, 'tag': 'WritingCommunity'},
#       {'start': 161, 'end': 178, 'tag': 'amwritingfiction'}],
#      'mentions': [{'start': 0,
#        'end': 14,
#        'username': 'AuthorJFuller',
#        'id': '448329810'}]},
#     'author_id': '1320819574317715463',
#     'text': '@AuthorJFuller Preparing to query and feeling anxious. Fortunately the local grocery is already stocking pumpkin spice everything. #amquerying #WritingCommunity #amwritingfiction',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562107241460891649'},
#    {'author_id': '715742118589947904',
#     'text': 'Pumpkin spice out yet?',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562107206803329024'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 10,
#        'username': 'Giants',
#        'id': '240734425'},
#       {'start': 13, 'end': 17, 'username': 'PFF', 'id': '87954771'}],
#      'urls': [{'start': 51,
#        'end': 74,
#        'url': 'https://t.co/uVfOQUurRC',
#        'expanded_url': 'http://nygnt.co/gn823',
#        'display_url': 'nygnt.co/gn823',
#        'images': [{'url': 'https://pbs.twimg.com/news_img/1562073464994820097/mE5zguOe?format=jpg&name=orig',
#          'width': 1280,
#          'height': 720},
#         {'url': 'https://pbs.twimg.com/news_img/1562073464994820097/mE5zguOe?format=jpg&name=150x150',
#          'width': 150,
#          'height': 150}],
#        'status': 200,
#        'title': 'Giants Now: PFF takeaways from win over Bengals',
#        'description': 'The news of the day for Giants fans on Tuesday, August 23, 2022.',
#        'unwound_url': 'https://www.giants.com/news/pff-giants-bengals-preseason-davis-webb-daniel-jones-alex-bachman-andrew-thomas'}]},
#     'author_id': '1520531882886123520',
#     'text': "RT @Giants: .@PFF's takeaways from Sunday night\n📰: https://t.co/uVfOQUurRC\n\nSip the $3 medium spiced &amp; iced pumpkin spice signature latte o…",
#     'public_metrics': {'retweet_count': 13,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562107178231615488'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 15,
#        'username': 'NatbyNature',
#        'id': '89014429'}],
#      'urls': [{'start': 82,
#        'end': 105,
#        'url': 'https://t.co/rOYf6IO9tT',
#        'expanded_url': 'https://twitter.com/NatbyNature/status/1561781781061304323/photo/1',
#        'display_url': 'pic.twitter.com/rOYf6IO9tT',
#        'media_key': '3_1561781778058289154'}],
#      'annotations': [{'start': 57,
#        'end': 79,
#        'probability': 0.6058,
#        'type': 'Product',
#        'normalized_text': 'Pumpkin Spice Latte SZN'}]},
#     'author_id': '2174166952',
#     'text': 'RT @NatbyNature: The Neidharts are waiting patiently for Pumpkin Spice Latte SZN. https://t.co/rOYf6IO9tT',
#     'public_metrics': {'retweet_count': 792,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'attachments': {'media_keys': ['3_1561781778058289154']},
#     'id': '1562106921552846852'},
#    {'entities': {'mentions': [{'start': 0,
#        'end': 16,
#        'username': 'spartan_phoenix',
#        'id': '174112760'},
#       {'start': 17, 'end': 27, 'username': 'QUIETRIOT', 'id': '268515375'},
#       {'start': 28,
#        'end': 42,
#        'username': 'fanpodnetwork',
#        'id': '4923363149'},
#       {'start': 43,
#        'end': 57,
#        'username': 'HairMetalCast',
#        'id': '1050470144017883136'},
#       {'start': 58,
#        'end': 72,
#        'username': '80sRockRadio1',
#        'id': '1111879032197517312'},
#       {'start': 73,
#        'end': 89,
#        'username': 'MetalMusicWatch',
#        'id': '969840276'}]},
#     'author_id': '172536397',
#     'text': '@spartan_phoenix @QUIETRIOT @fanpodnetwork @HairMetalCast @80sRockRadio1 @MetalMusicWatch Not yet but I am seeing more pumpkin spice so soon lol',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562106921192198146'},
#    {'entities': {'mentions': [{'start': 0,
#        'end': 10,
#        'username': 'snarkeigh',
#        'id': '1227423104839946240'}]},
#     'author_id': '56293953',
#     'text': '@snarkeigh Gurrrl Dunkin released Pumpkin spice last week!! &amp; Crispy Cream got them pumpkin spice donuts!!',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562106742955298817'},
#    {'author_id': '1240542870',
#     'text': 'This pumpkin spice iced coffee is doing things to me',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562106721484652545'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 14,
#        'username': 'whatlyddid',
#        'id': '2565247248'}],
#      'annotations': [{'start': 56,
#        'end': 57,
#        'probability': 0.8972,
#        'type': 'Place',
#        'normalized_text': 'UK'},
#       {'start': 82,
#        'end': 90,
#        'probability': 0.4973,
#        'type': 'Organization',
#        'normalized_text': 'Debenhams'},
#       {'start': 96,
#        'end': 111,
#        'probability': 0.6014,
#        'type': 'Organization',
#        'normalized_text': 'House Of Frasers'}]},
#     'author_id': '184586888',
#     'text': 'RT @whatlyddid: Petition for Target to come over to the UK and fill all the empty Debenhams and House Of Frasers with their dollar spot pum…',
#     'public_metrics': {'retweet_count': 10,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562106572544827394'},
#    {'entities': {'mentions': [{'start': 0,
#        'end': 14,
#        'username': 'myronjclifton',
#        'id': '1483794432793010178'}],
#      'urls': [{'start': 268,
#        'end': 291,
#        'url': 'https://t.co/fOIQahd5bE',
#        'expanded_url': 'https://twitter.com/Bigdaddyksizzle/status/1562106571542372352/photo/1',
#        'display_url': 'pic.twitter.com/fOIQahd5bE',
#        'media_key': '16_1562106565167030273'}],
#      'annotations': [{'start': 70,
#        'end': 87,
#        'probability': 0.5826,
#        'type': 'Organization',
#        'normalized_text': 'Louisville Slugger'}]},
#     'author_id': '589404880',
#     'text': "@myronjclifton Awwwww....Hellll....nawww !!!\n\n(Proceeds to store with Louisville Slugger in hand to bust up every single bag....send bail/commissary 💰 (honey buns/noodles aren't cheap,ya'll).\n\nLeaves haven't turned yet and they're already pimping Pumpkin Spice ish... https://t.co/fOIQahd5bE",
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'attachments': {'media_keys': ['16_1562106565167030273']},
#     'id': '1562106571542372352'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 13,
#        'username': 'snarkeigh',
#        'id': '1227423104839946240'}],
#      'urls': [{'start': 75,
#        'end': 98,
#        'url': 'https://t.co/iVDfRg6N0x',
#        'expanded_url': 'https://twitter.com/allreactionvidz/status/1162954321916547073/video/1',
#        'display_url': 'pic.twitter.com/iVDfRg6N0x',
#        'media_key': '7_1162954272918646784'}]},
#     'author_id': '1924084195',
#     'text': 'RT @snarkeigh: It’s the end of August and still no pumpkin spice anywhere… https://t.co/iVDfRg6N0x',
#     'public_metrics': {'retweet_count': 221,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'attachments': {'media_keys': ['7_1162954272918646784']},
#     'id': '1562106526483054593'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 16,
#        'username': 'shawdeeiipee',
#        'id': '80718253'}]},
#     'author_id': '1089210154996895744',
#     'text': 'RT @shawdeeiipee: One hate train I’ll absolutely stand behind is pumpkin spice/flavor/scent anything.',
#     'public_metrics': {'retweet_count': 11,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562106450662531077'},
#    {'entities': {'mentions': [{'start': 0,
#        'end': 11,
#        'username': 'delabarcel',
#        'id': '566825321'}]},
#     'author_id': '722220305108873216',
#     'text': '@delabarcel pumpkin spice benadryl',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562106325349421057'},
#    {'author_id': '51521178',
#     'text': 'Get Back Into Pumpkin Spice Season With Martha Stewart’s New CBD Gummies https://t.co/s9nRCvmRUx',
#     'entities': {'urls': [{'start': 73,
#        'end': 96,
#        'url': 'https://t.co/s9nRCvmRUx',
#        'expanded_url': 'https://www.usmagazine.com/shop-with-us/news/martha-stewart-pumpkin-spice-cbd-gummies/',
#        'display_url': 'usmagazine.com/shop-with-us/n…',
#        'status': 200,
#        'title': 'Get Back Into Pumpkin Spice Season With Martha Stewart’s New CBD Gummies',
#        'description': 'Martha Stewart just launched Pumpkin Spice CBD Wellness Gummies that she developed herself — shop for a limited time',
#        'unwound_url': 'https://www.usmagazine.com/shop-with-us/news/martha-stewart-pumpkin-spice-cbd-gummies/'}],
#      'annotations': [{'start': 40,
#        'end': 53,
#        'probability': 0.9656,
#        'type': 'Person',
#        'normalized_text': 'Martha Stewart'}]},
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562106316964777986'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 13,
#        'username': 'snarkeigh',
#        'id': '1227423104839946240'}],
#      'urls': [{'start': 75,
#        'end': 98,
#        'url': 'https://t.co/iVDfRg6N0x',
#        'expanded_url': 'https://twitter.com/allreactionvidz/status/1162954321916547073/video/1',
#        'display_url': 'pic.twitter.com/iVDfRg6N0x',
#        'media_key': '7_1162954272918646784'}]},
#     'author_id': '829964234',
#     'text': 'RT @snarkeigh: It’s the end of August and still no pumpkin spice anywhere… https://t.co/iVDfRg6N0x',
#     'public_metrics': {'retweet_count': 221,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'attachments': {'media_keys': ['7_1162954272918646784']},
#     'id': '1562106266427744257'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 15,
#        'username': 'MiiyaUwU_EN',
#        'id': '1413434741055885320'}],
#      'annotations': [{'start': 49,
#        'end': 77,
#        'probability': 0.7695,
#        'type': 'Product',
#        'normalized_text': 'Pumpkin Spice Latte Starbucks'}]},
#     'author_id': '1193084902826053632',
#     'text': 'RT @MiiyaUwU_EN: I remember a white, and I mean, Pumpkin Spice Latte Starbucks basic leftist milquetoast hwite garden variety furry woman a…',
#     'public_metrics': {'retweet_count': 1,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562106164913278976'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 16,
#        'username': 'shawdeeiipee',
#        'id': '80718253'}]},
#     'author_id': '307572594',
#     'text': 'RT @shawdeeiipee: One hate train I’ll absolutely stand behind is pumpkin spice/flavor/scent anything.',
#     'public_metrics': {'retweet_count': 11,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562106159619887106'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 16,
#        'username': 'shawdeeiipee',
#        'id': '80718253'}]},
#     'author_id': '129095360',
#     'text': 'RT @shawdeeiipee: One hate train I’ll absolutely stand behind is pumpkin spice/flavor/scent anything.',
#     'public_metrics': {'retweet_count': 11,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562106157216538627'},
#    {'entities': {'mentions': [{'start': 0,
#        'end': 8,
#        'username': 'Buukkin',
#        'id': '1038300685'}]},
#     'author_id': '1070467948026978304',
#     'text': '@Buukkin sipping my still-exclusive-to-employees pumpkin spice latte because you’re so right, i deserve both treats 🥰🥰',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562106040572862467'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 18,
#        'username': 'ohemgeeijizzed',
#        'id': '2980848424'}],
#      'annotations': [{'start': 85,
#        'end': 93,
#        'probability': 0.64,
#        'type': 'Other',
#        'normalized_text': 'halloween'}]},
#     'author_id': '1156396485119844353',
#     'text': 'RT @ohemgeeijizzed: i can’t wait for crisp air in the mornings, houses decorated for halloween, crunchy leaves, fall clothes and pumpkin sp…',
#     'public_metrics': {'retweet_count': 111,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562106033815916544'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 15,
#        'username': 'NatbyNature',
#        'id': '89014429'}],
#      'urls': [{'start': 82,
#        'end': 105,
#        'url': 'https://t.co/rOYf6IO9tT',
#        'expanded_url': 'https://twitter.com/NatbyNature/status/1561781781061304323/photo/1',
#        'display_url': 'pic.twitter.com/rOYf6IO9tT',
#        'media_key': '3_1561781778058289154'}],
#      'annotations': [{'start': 57,
#        'end': 79,
#        'probability': 0.6058,
#        'type': 'Product',
#        'normalized_text': 'Pumpkin Spice Latte SZN'}]},
#     'author_id': '1492182271557660674',
#     'text': 'RT @NatbyNature: The Neidharts are waiting patiently for Pumpkin Spice Latte SZN. https://t.co/rOYf6IO9tT',
#     'public_metrics': {'retweet_count': 792,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'attachments': {'media_keys': ['3_1561781778058289154']},
#     'id': '1562105805893156864'},
#    {'author_id': '2303693131',
#     'text': 'I want spooky adrenaline and pumpkin spice flowing through my veins',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562105797353435136'},
#    {'entities': {'hashtags': [{'start': 24, 'end': 33, 'tag': 'Hokkaido'},
#       {'start': 47, 'end': 52, 'tag': 'gift'},
#       {'start': 56, 'end': 67, 'tag': 'MotherSoil'},
#       {'start': 94, 'end': 98, 'tag': 'Eat'}],
#      'mentions': [{'start': 3,
#        'end': 18,
#        'username': 'MnicaSofaPrez1',
#        'id': '1513894048750317579'}]},
#     'author_id': '821611876232691713',
#     'text': 'RT @MnicaSofaPrez1: The #Hokkaido pumpkin is a #gift of #MotherSoil, even the skin is edible! #Eat it raw, roasted, steamed, boiled, sautée…',
#     'public_metrics': {'retweet_count': 33,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562105695800942598'},
#    {'author_id': '2986186101',
#     'text': "It is time to spice up your life with the Callie's Hot Little Biscuit pumpkin spice biscuit!! Grab the most anticipated fall special at our Charleston eateries all season long! Hot littles available only on the weekends at King St &amp; sandwich sized everyday at City Market! https://t.co/0Rog4DCuSb",
#     'entities': {'urls': [{'start': 277,
#        'end': 300,
#        'url': 'https://t.co/0Rog4DCuSb',
#        'expanded_url': 'https://twitter.com/CalliesHLB/status/1562105663429525504/photo/1',
#        'display_url': 'pic.twitter.com/0Rog4DCuSb',
#        'media_key': '3_1562105651064705024'},
#       {'start': 277,
#        'end': 300,
#        'url': 'https://t.co/0Rog4DCuSb',
#        'expanded_url': 'https://twitter.com/CalliesHLB/status/1562105663429525504/photo/1',
#        'display_url': 'pic.twitter.com/0Rog4DCuSb',
#        'media_key': '3_1562105657205170177'}],
#      'annotations': [{'start': 42,
#        'end': 47,
#        'probability': 0.7313,
#        'type': 'Person',
#        'normalized_text': 'Callie'},
#       {'start': 140,
#        'end': 149,
#        'probability': 0.6248,
#        'type': 'Place',
#        'normalized_text': 'Charleston'},
#       {'start': 223,
#        'end': 229,
#        'probability': 0.7107,
#        'type': 'Place',
#        'normalized_text': 'King St'},
#       {'start': 260,
#        'end': 270,
#        'probability': 0.5592,
#        'type': 'Place',
#        'normalized_text': 'City Market'}]},
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 1,
#      'quote_count': 0},
#     'attachments': {'media_keys': ['3_1562105651064705024',
#       '3_1562105657205170177']},
#     'id': '1562105663429525504'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 15,
#        'username': 'NatbyNature',
#        'id': '89014429'}],
#      'urls': [{'start': 82,
#        'end': 105,
#        'url': 'https://t.co/rOYf6IO9tT',
#        'expanded_url': 'https://twitter.com/NatbyNature/status/1561781781061304323/photo/1',
#        'display_url': 'pic.twitter.com/rOYf6IO9tT',
#        'media_key': '3_1561781778058289154'}],
#      'annotations': [{'start': 57,
#        'end': 79,
#        'probability': 0.6058,
#        'type': 'Product',
#        'normalized_text': 'Pumpkin Spice Latte SZN'}]},
#     'author_id': '1424980169127833603',
#     'text': 'RT @NatbyNature: The Neidharts are waiting patiently for Pumpkin Spice Latte SZN. https://t.co/rOYf6IO9tT',
#     'public_metrics': {'retweet_count': 792,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'attachments': {'media_keys': ['3_1561781778058289154']},
#     'id': '1562105650502664193'},
#    {'author_id': '162754404',
#     'text': '¿Me mandan un pumpkin spice latte?',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 1,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562105564695609345'},
#    {'author_id': '2685800288',
#     'text': 'trop hâte ça va être la saison des pumpkin spice latte matin midi goûter soir 😼😼',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 1,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562105501013446659'},
#    {'author_id': '1708290942',
#     'text': 'Pumpkin spice latte soon to be a poop valuing $4',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562105454058258433'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 13,
#        'username': 'snarkeigh',
#        'id': '1227423104839946240'}],
#      'urls': [{'start': 75,
#        'end': 98,
#        'url': 'https://t.co/iVDfRg6N0x',
#        'expanded_url': 'https://twitter.com/allreactionvidz/status/1162954321916547073/video/1',
#        'display_url': 'pic.twitter.com/iVDfRg6N0x',
#        'media_key': '7_1162954272918646784'}]},
#     'author_id': '1148679589',
#     'text': 'RT @snarkeigh: It’s the end of August and still no pumpkin spice anywhere… https://t.co/iVDfRg6N0x',
#     'public_metrics': {'retweet_count': 221,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'attachments': {'media_keys': ['7_1162954272918646784']},
#     'id': '1562105158460473346'},
#    {'entities': {'mentions': [{'start': 0,
#        'end': 16,
#        'username': 'StandOutSocksUK',
#        'id': '1417227026881200129'}]},
#     'author_id': '386714333',
#     'text': '@StandOutSocksUK Pumpkin spice',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562105116962050048'},
#    {'entities': {'mentions': [{'start': 0,
#        'end': 10,
#        'username': 'DeconTyke',
#        'id': '124957875'}]},
#     'author_id': '951227503217168385',
#     'text': '@DeconTyke No, pumpkin spice for life ❤️',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562105064218656774'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 16,
#        'username': 'DougJBalloon',
#        'id': '22998311'}],
#      'annotations': [{'start': 95,
#        'end': 103,
#        'probability': 0.9975,
#        'type': 'Person',
#        'normalized_text': 'Joe Biden'}]},
#     'author_id': '1479753742870216705',
#     'text': 'RT @DougJBalloon: Pumpkin spice latte season is almost upon us. Here’s why that’s bad news for Joe Biden.',
#     'public_metrics': {'retweet_count': 496,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562104911784976385'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 14,
#        'username': 'LainaRauma',
#        'id': '25946224'}],
#      'urls': [{'start': 76,
#        'end': 99,
#        'url': 'https://t.co/SJcIWGq4sZ',
#        'expanded_url': 'https://twitter.com/LainaRauma/status/1562104015852150789/video/1',
#        'display_url': 'pic.twitter.com/SJcIWGq4sZ',
#        'media_key': '7_1562103969651970055'}]},
#     'author_id': '174938330',
#     'text': 'RT @LainaRauma: Pumpkin Spice. Dance Class Pt. 2 available THURSDAY 9AM PST https://t.co/SJcIWGq4sZ',
#     'public_metrics': {'retweet_count': 1,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'attachments': {'media_keys': ['7_1562103969651970055']},
#     'id': '1562104650861629442'},
#    {'author_id': '1706022390',
#     'text': 'First pumpkin spice latte of the season 🎃👻',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562104627331567619'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 13,
#        'username': 'markaduck',
#        'id': '218889555'}],
#      'urls': [{'start': 51,
#        'end': 74,
#        'url': 'https://t.co/ytSHKhazYN',
#        'expanded_url': 'https://twitter.com/UTBarstool/status/1561498867765485575/video/1',
#        'display_url': 'pic.twitter.com/ytSHKhazYN',
#        'media_key': '7_1561498793077530625'}],
#      'annotations': [{'start': 15,
#        'end': 27,
#        'probability': 0.3477,
#        'type': 'Product',
#        'normalized_text': 'Pumpkin Spice'},
#       {'start': 40,
#        'end': 48,
#        'probability': 0.7276,
#        'type': 'Organization',
#        'normalized_text': 'Starbucks'}]},
#     'author_id': '1346272965248352261',
#     'text': 'RT @markaduck: Pumpkin Spice is back at Starbucks  https://t.co/ytSHKhazYN',
#     'public_metrics': {'retweet_count': 24,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'attachments': {'media_keys': ['7_1561498793077530625']},
#     'id': '1562104585191411712'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 13,
#        'username': 'DrMayhem_',
#        'id': '98197370'}],
#      'urls': [{'start': 69,
#        'end': 92,
#        'url': 'https://t.co/yzaoAspdrK',
#        'expanded_url': 'https://twitter.com/DrMayhem_/status/1561105045843689473/video/1',
#        'display_url': 'pic.twitter.com/yzaoAspdrK',
#        'media_key': '7_1561104980844728320'}],
#      'annotations': [{'start': 42,
#        'end': 54,
#        'probability': 0.2644,
#        'type': 'Other',
#        'normalized_text': 'Pumpkin Spice'}]},
#     'author_id': '1099854442248237056',
#     'text': 'RT @DrMayhem_: Preparing for the Fall and Pumpkin Spice season like… https://t.co/yzaoAspdrK',
#     'public_metrics': {'retweet_count': 943,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'attachments': {'media_keys': ['7_1561104980844728320']},
#     'id': '1562104528647905280'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 13,
#        'username': 'DrMayhem_',
#        'id': '98197370'}],
#      'urls': [{'start': 69,
#        'end': 92,
#        'url': 'https://t.co/yzaoAspdrK',
#        'expanded_url': 'https://twitter.com/DrMayhem_/status/1561105045843689473/video/1',
#        'display_url': 'pic.twitter.com/yzaoAspdrK',
#        'media_key': '7_1561104980844728320'}],
#      'annotations': [{'start': 42,
#        'end': 54,
#        'probability': 0.2644,
#        'type': 'Other',
#        'normalized_text': 'Pumpkin Spice'}]},
#     'author_id': '1246289592',
#     'text': 'RT @DrMayhem_: Preparing for the Fall and Pumpkin Spice season like… https://t.co/yzaoAspdrK',
#     'public_metrics': {'retweet_count': 943,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'attachments': {'media_keys': ['7_1561104980844728320']},
#     'id': '1562104469038440448'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 15,
#        'username': 'ungodlythin',
#        'id': '1415437570532642817'}]},
#     'author_id': '1547087621259726848',
#     'text': 'RT @ungodlythin: 60 cal veg4n pumpkin spice mug cake recipe 🧵 for edtwt! 🍂 \n\nactual cake in pic!\n\n♡/↻ are appreciated \U0001faf6🏻 https://t.co/9cd0D…',
#     'public_metrics': {'retweet_count': 60,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562104448486342658'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 15,
#        'username': 'NatbyNature',
#        'id': '89014429'}],
#      'urls': [{'start': 82,
#        'end': 105,
#        'url': 'https://t.co/rOYf6IO9tT',
#        'expanded_url': 'https://twitter.com/NatbyNature/status/1561781781061304323/photo/1',
#        'display_url': 'pic.twitter.com/rOYf6IO9tT',
#        'media_key': '3_1561781778058289154'}],
#      'annotations': [{'start': 57,
#        'end': 79,
#        'probability': 0.6058,
#        'type': 'Product',
#        'normalized_text': 'Pumpkin Spice Latte SZN'}]},
#     'author_id': '606829185',
#     'text': 'RT @NatbyNature: The Neidharts are waiting patiently for Pumpkin Spice Latte SZN. https://t.co/rOYf6IO9tT',
#     'public_metrics': {'retweet_count': 792,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'attachments': {'media_keys': ['3_1561781778058289154']},
#     'id': '1562104407323451393'},
#    {'author_id': '3055520112',
#     'text': 'Oogie Boogie tortilla moon is up on the DCA entrance 😍 I truly need my pumpkin spice back now',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562104394513932288',
#     'entities': {'annotations': [{'start': 0,
#        'end': 25,
#        'probability': 0.3841,
#        'type': 'Product',
#        'normalized_text': 'Oogie Boogie tortilla moon'}]}},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 13,
#        'username': 'snarkeigh',
#        'id': '1227423104839946240'}],
#      'urls': [{'start': 75,
#        'end': 98,
#        'url': 'https://t.co/iVDfRg6N0x',
#        'expanded_url': 'https://twitter.com/allreactionvidz/status/1162954321916547073/video/1',
#        'display_url': 'pic.twitter.com/iVDfRg6N0x',
#        'media_key': '7_1162954272918646784'}]},
#     'author_id': '722045223254237184',
#     'text': 'RT @snarkeigh: It’s the end of August and still no pumpkin spice anywhere… https://t.co/iVDfRg6N0x',
#     'public_metrics': {'retweet_count': 221,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'attachments': {'media_keys': ['7_1162954272918646784']},
#     'id': '1562104216696545283'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 14,
#        'username': 'jaybeez112',
#        'id': '1169691326'}]},
#     'author_id': '332721482',
#     'text': "RT @jaybeez112: Easy with all the pumpkin spice tweets it's still August, psychopaths",
#     'public_metrics': {'retweet_count': 2,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562104162757685248'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 16,
#        'username': 'evelinacloud',
#        'id': '1532452257601441792'}]},
#     'author_id': '1551456882535055362',
#     'text': 'RT @evelinacloud: i’m ready for rainy fall days &amp; pumpkin spice lattes',
#     'public_metrics': {'retweet_count': 83,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562104137017442305'},
#    {'author_id': '1322617937275047936',
#     'text': 'ja uz se tak tesim na pumpkin spice latte!!☕\U0001faf6🏻',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562104068818014211'},
#    {'author_id': '629867260',
#     'text': 'pumpkin spice latte season is hereeeeee 🎃',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562104043090108418'},
#    {'author_id': '25946224',
#     'text': 'Pumpkin Spice. Dance Class Pt. 2 available THURSDAY 9AM PST https://t.co/SJcIWGq4sZ',
#     'entities': {'urls': [{'start': 60,
#        'end': 83,
#        'url': 'https://t.co/SJcIWGq4sZ',
#        'expanded_url': 'https://twitter.com/LainaRauma/status/1562104015852150789/video/1',
#        'display_url': 'pic.twitter.com/SJcIWGq4sZ',
#        'media_key': '7_1562103969651970055'}]},
#     'public_metrics': {'retweet_count': 1,
#      'reply_count': 1,
#      'like_count': 21,
#      'quote_count': 1},
#     'attachments': {'media_keys': ['7_1562103969651970055']},
#     'id': '1562104015852150789'},
#    {'entities': {'mentions': [{'start': 0,
#        'end': 14,
#        'username': 'RealChrisSays',
#        'id': '1394126240550985728'}],
#      'annotations': [{'start': 144,
#        'end': 163,
#        'probability': 0.7974,
#        'type': 'Product',
#        'normalized_text': 'Pumpkin Spice Junkie'}]},
#     'author_id': '829576036622835712',
#     'text': '@RealChrisSays Yup My daughter Who is 32 is excited like a five year old for Sept 1 bc that’s when pumpkin everything starts being sold She’s a Pumpkin Spice Junkie',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562103984458010624'},
#    {'author_id': '887381788263411712',
#     'text': 'nie mogę się doczekać picia pumpkin spice latte, zakładania płaszczy i brązowo-beżowych outfitów, robienia cinnamon rolls, oglądania wieczorami gilmore girls, komentowania raz w tygodniu top model, uczenia się przy świeczce.. mogłabym wymieniać w nieskończoność 🍁🌰🎃🤎',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 2,
#      'like_count': 13,
#      'quote_count': 0},
#     'id': '1562103972680310784'},
#    {'entities': {'mentions': [{'start': 0,
#        'end': 7,
#        'username': '_BHRiS',
#        'id': '32259570'}],
#      'urls': [{'start': 42,
#        'end': 65,
#        'url': 'https://t.co/kn8lH4Im2D',
#        'expanded_url': 'https://twitter.com/elidaniamaya/status/1562103831407857666/photo/1',
#        'display_url': 'pic.twitter.com/kn8lH4Im2D',
#        'media_key': '16_1562103825988812802'}]},
#     'geo': {'place_id': '8173485c72e78ca5'},
#     'author_id': '333720710',
#     'text': '@_BHRiS Anyone who drinks pumpkin spice…🙂 https://t.co/kn8lH4Im2D',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'attachments': {'media_keys': ['16_1562103825988812802']},
#     'id': '1562103831407857666'},
#    {'entities': {'hashtags': [{'start': 156,
#        'end': 168,
#        'tag': 'unsubscribe'}],
#      'mentions': [{'start': 0,
#        'end': 11,
#        'username': 'lubbitytay',
#        'id': '1101657821094035457'}],
#      'urls': [{'start': 181,
#        'end': 204,
#        'url': 'https://t.co/j6DjatHplz',
#        'expanded_url': 'https://twitter.com/dunkindonuts/status/1562103739082842112/video/1',
#        'display_url': 'pic.twitter.com/j6DjatHplz',
#        'media_key': '13_1560658709692690432'}],
#      'annotations': [{'start': 69,
#        'end': 91,
#        'probability': 0.5999,
#        'type': 'Product',
#        'normalized_text': 'Pumpkin Cream Cold Brew'},
#       {'start': 99,
#        'end': 127,
#        'probability': 0.9241,
#        'type': 'Product',
#        'normalized_text': 'Pumpkin Spice Signature Latte'}]},
#     'author_id': '8771022',
#     'text': '@lubbitytay You’re in! We’ll make sure you don’t miss your $3 medium Pumpkin Cream Cold Brew or $3 Pumpkin Spice Signature Latte. How pumped are you? Reply #unsubscribe to opt-out. https://t.co/j6DjatHplz',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'attachments': {'media_keys': ['13_1560658709692690432']},
#     'id': '1562103739082842112'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 13,
#        'username': 'DrMayhem_',
#        'id': '98197370'}],
#      'urls': [{'start': 69,
#        'end': 92,
#        'url': 'https://t.co/yzaoAspdrK',
#        'expanded_url': 'https://twitter.com/DrMayhem_/status/1561105045843689473/video/1',
#        'display_url': 'pic.twitter.com/yzaoAspdrK',
#        'media_key': '7_1561104980844728320'}],
#      'annotations': [{'start': 42,
#        'end': 54,
#        'probability': 0.2644,
#        'type': 'Other',
#        'normalized_text': 'Pumpkin Spice'}]},
#     'author_id': '16471569',
#     'text': 'RT @DrMayhem_: Preparing for the Fall and Pumpkin Spice season like… https://t.co/yzaoAspdrK',
#     'public_metrics': {'retweet_count': 943,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'attachments': {'media_keys': ['7_1561104980844728320']},
#     'id': '1562103734687129600'},
#    {'author_id': '857412915879710721',
#     'text': 'You mean to tell me that pumpkin spice is back at Starbucks AND Spiderman is back in theaters all in the same week?',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562103715900825600',
#     'entities': {'annotations': [{'start': 50,
#        'end': 72,
#        'probability': 0.3748,
#        'type': 'Organization',
#        'normalized_text': 'Starbucks AND Spiderman'}]}},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 14,
#        'username': 'buildabear',
#        'id': '14997308'}],
#      'annotations': [{'start': 92,
#        'end': 109,
#        'probability': 0.7036,
#        'type': 'Product',
#        'normalized_text': 'Pumpkin Spice Bear'}]},
#     'author_id': '1184619111474696198',
#     'text': 'RT @buildabear: It’s back in time for PSL season! Give the gift of caffeinated cuddles with Pumpkin Spice Bear! This glittery friend is pum…',
#     'public_metrics': {'retweet_count': 5,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562103531083112448'},
#    {'author_id': '28239850',
#     'text': "I found pumpkin spice moon pies. So all's good.",
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562103501207097344'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 13,
#        'username': 'snarkeigh',
#        'id': '1227423104839946240'}],
#      'urls': [{'start': 75,
#        'end': 98,
#        'url': 'https://t.co/iVDfRg6N0x',
#        'expanded_url': 'https://twitter.com/allreactionvidz/status/1162954321916547073/video/1',
#        'display_url': 'pic.twitter.com/iVDfRg6N0x',
#        'media_key': '7_1162954272918646784'}]},
#     'author_id': '1253357892109033473',
#     'text': 'RT @snarkeigh: It’s the end of August and still no pumpkin spice anywhere… https://t.co/iVDfRg6N0x',
#     'public_metrics': {'retweet_count': 221,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'attachments': {'media_keys': ['7_1162954272918646784']},
#     'id': '1562103295698784257'},
#    {'author_id': '1460802259059572737',
#     'text': 'I’m going on strike y’all. I’m not doing a goddamned thing until Starbucks releases the pumpkin spice latte.',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 1,
#      'quote_count': 0},
#     'id': '1562103249414414337',
#     'entities': {'annotations': [{'start': 65,
#        'end': 73,
#        'probability': 0.8099,
#        'type': 'Organization',
#        'normalized_text': 'Starbucks'}]}},
#    {'author_id': '596141083',
#     'text': 'wont let Society make me feel bad about counting down the days until pumpkin spice lattes are back\n(7 if ur wondering)',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 1,
#      'quote_count': 0},
#     'id': '1562103159023173634'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 17,
#        'username': 'TomAckermanWx',
#        'id': '68354597'}],
#      'annotations': [{'start': 106,
#        'end': 118,
#        'probability': 0.6888,
#        'type': 'Product',
#        'normalized_text': 'Pumpkin Spice'}]},
#     'author_id': '1192503719021219840',
#     'text': 'RT @TomAckermanWx: My wife texted me this picture from the grocery store. She really knows how to push my Pumpkin Spice hating buttons. 😂 h…',
#     'public_metrics': {'retweet_count': 3,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562103028139835392'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 15,
#        'username': 'NatbyNature',
#        'id': '89014429'}],
#      'urls': [{'start': 82,
#        'end': 105,
#        'url': 'https://t.co/rOYf6IO9tT',
#        'expanded_url': 'https://twitter.com/NatbyNature/status/1561781781061304323/photo/1',
#        'display_url': 'pic.twitter.com/rOYf6IO9tT',
#        'media_key': '3_1561781778058289154'}],
#      'annotations': [{'start': 57,
#        'end': 79,
#        'probability': 0.6058,
#        'type': 'Product',
#        'normalized_text': 'Pumpkin Spice Latte SZN'}]},
#     'author_id': '951414669482348544',
#     'text': 'RT @NatbyNature: The Neidharts are waiting patiently for Pumpkin Spice Latte SZN. https://t.co/rOYf6IO9tT',
#     'public_metrics': {'retweet_count': 792,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'attachments': {'media_keys': ['3_1561781778058289154']},
#     'id': '1562102906815483904'},
#    {'author_id': '1341446898645872641',
#     'text': 'Pumpkin spice creamer is back at the stores😏',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562102893460631553',
#     'entities': {'annotations': [{'start': 0,
#        'end': 20,
#        'probability': 0.4759,
#        'type': 'Product',
#        'normalized_text': 'Pumpkin spice creamer'}]}},
#    {'author_id': '942851581053083648',
#     'text': "I'm so ready to be able to get pumpkin spice cold brews again 🤤",
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562102838213324801'},
#    {'author_id': '1373741343613333506',
#     'text': "the Pumpkin Spice  Oreos are freakin' amazing.",
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562102819695493121',
#     'entities': {'annotations': [{'start': 4,
#        'end': 23,
#        'probability': 0.7518,
#        'type': 'Product',
#        'normalized_text': 'Pumpkin Spice Oreos'}]}},
#    {'entities': {'hashtags': [{'start': 162,
#        'end': 175,
#        'tag': 'pumpkinspice'},
#       {'start': 176, 'end': 186, 'tag': 'fallvibes'}],
#      'mentions': [{'start': 155,
#        'end': 160,
#        'username': 'Etsy',
#        'id': '11522502'}],
#      'urls': [{'start': 127,
#        'end': 150,
#        'url': 'https://t.co/l4oyrGpXIc',
#        'expanded_url': 'https://etsy.me/3pC0v5C',
#        'display_url': 'etsy.me/3pC0v5C',
#        'images': [{'url': 'https://pbs.twimg.com/news_img/1562102743006863360/qR1MMTi2?format=jpg&name=orig',
#          'width': 570,
#          'height': 570},
#         {'url': 'https://pbs.twimg.com/news_img/1562102743006863360/qR1MMTi2?format=jpg&name=150x150',
#          'width': 150,
#          'height': 150}],
#        'status': 200,
#        'title': 'Pumpkin Spice Sweatshirt Cute Coffee Lover Shirt Pumpkin - Etsy',
#        'description': 'This Gender-Neutral Adult Sweatshirts item is sold by CloverandAnnie. Ships from San Jose, CA. Listed on Aug 23, 2022',
#        'unwound_url': 'https://www.etsy.com/listing/1277554960/pumpkin-spice-sweatshirt-cute-coffee?utm_medium=SellerListingTools&utm_campaign=Share&utm_source=Twitter&share_time=1661269226000&utm_term=so.slt'}],
#      'annotations': [{'start': 96,
#        'end': 107,
#        'probability': 0.6111,
#        'type': 'Other',
#        'normalized_text': 'Thanksgiving'}]},
#     'author_id': '122796840',
#     'text': 'Pumpkin Spice Sweatshirt,, Cute Coffee Lover Shirt, Pumpkin , PSL Lover Shirt, Fall Sweatshirt, Thanksgiving Gift, Autum Shirt https://t.co/l4oyrGpXIc via @Etsy \n#pumpkinspice #fallvibes',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562102739647217664'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 13,
#        'username': 'DrMayhem_',
#        'id': '98197370'}],
#      'urls': [{'start': 69,
#        'end': 92,
#        'url': 'https://t.co/yzaoAspdrK',
#        'expanded_url': 'https://twitter.com/DrMayhem_/status/1561105045843689473/video/1',
#        'display_url': 'pic.twitter.com/yzaoAspdrK',
#        'media_key': '7_1561104980844728320'}]},
#     'author_id': '1919324462',
#     'text': 'RT @DrMayhem_: Preparing for the Fall and Pumpkin Spice season like… https://t.co/yzaoAspdrK',
#     'public_metrics': {'retweet_count': 943,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'attachments': {'media_keys': ['7_1561104980844728320']},
#     'id': '1562102711444639745'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 18,
#        'username': 'MattPostSaysHi',
#        'id': '2871453981'}],
#      'urls': [{'start': 78,
#        'end': 101,
#        'url': 'https://t.co/4mBPyXmfmG',
#        'expanded_url': 'https://twitter.com/VideosFolder/status/1499870838178390027/video/1',
#        'display_url': 'pic.twitter.com/4mBPyXmfmG',
#        'media_key': '7_1499870788622688263'}]},
#     'author_id': '753939205030612992',
#     'text': 'RT @MattPostSaysHi: Me: (an adult)\n\nMe: thinking of pumpkin spice coming back https://t.co/4mBPyXmfmG',
#     'public_metrics': {'retweet_count': 232,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'attachments': {'media_keys': ['7_1499870788622688263']},
#     'id': '1562102658797895681'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 13,
#        'username': 'markaduck',
#        'id': '218889555'}],
#      'urls': [{'start': 51,
#        'end': 74,
#        'url': 'https://t.co/ytSHKhazYN',
#        'expanded_url': 'https://twitter.com/UTBarstool/status/1561498867765485575/video/1',
#        'display_url': 'pic.twitter.com/ytSHKhazYN',
#        'media_key': '7_1561498793077530625'}],
#      'annotations': [{'start': 15,
#        'end': 27,
#        'probability': 0.3477,
#        'type': 'Product',
#        'normalized_text': 'Pumpkin Spice'},
#       {'start': 40,
#        'end': 48,
#        'probability': 0.7276,
#        'type': 'Organization',
#        'normalized_text': 'Starbucks'}]},
#     'author_id': '753939205030612992',
#     'text': 'RT @markaduck: Pumpkin Spice is back at Starbucks  https://t.co/ytSHKhazYN',
#     'public_metrics': {'retweet_count': 24,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'attachments': {'media_keys': ['7_1561498793077530625']},
#     'id': '1562102625205714945'},
#    {'entities': {'hashtags': [{'start': 42, 'end': 50, 'tag': 'Sticker'},
#       {'start': 51, 'end': 64, 'tag': 'BasicPumpkin'},
#       {'start': 65, 'end': 76, 'tag': 'SpiceBitch'},
#       {'start': 77, 'end': 91, 'tag': 'theacedcasino'},
#       {'start': 92, 'end': 102, 'tag': 'EtsyEmail'}],
#      'urls': [{'start': 105,
#        'end': 128,
#        'url': 'https://t.co/c2EpoThjrZ',
#        'expanded_url': 'https://www.etsy.com/listing/1269549574/basic-pumpkin-spice-bitch-25-sticker',
#        'display_url': 'etsy.com/listing/126954…',
#        'images': [{'url': 'https://pbs.twimg.com/news_img/1562102580645613568/0n22OrYv?format=jpg&name=orig',
#          'width': 570,
#          'height': 570},
#         {'url': 'https://pbs.twimg.com/news_img/1562102580645613568/0n22OrYv?format=jpg&name=150x150',
#          'width': 150,
#          'height': 150}],
#        'status': 200,
#        'title': 'Basic Pumpkin Spice Bitch 2.5 Sticker - Etsy',
#        'description': 'This Laptop Decals item by AceFlorins has 3 favorites from Etsy shoppers. Ships from Rowland Heights, CA. Listed on Aug 10, 2022',
#        'unwound_url': 'https://www.etsy.com/listing/1269549574/basic-pumpkin-spice-bitch-25-sticker'},
#       {'start': 129,
#        'end': 152,
#        'url': 'https://t.co/tpJw8wFvPB',
#        'expanded_url': 'https://twitter.com/GRStest/status/1562102576119947265/photo/1',
#        'display_url': 'pic.twitter.com/tpJw8wFvPB',
#        'media_key': '3_1562102533711331330'},
#       {'start': 129,
#        'end': 152,
#        'url': 'https://t.co/tpJw8wFvPB',
#        'expanded_url': 'https://twitter.com/GRStest/status/1562102576119947265/photo/1',
#        'display_url': 'pic.twitter.com/tpJw8wFvPB',
#        'media_key': '3_1562102558973657088'}]},
#     'author_id': '4492998268',
#     'text': 'Basic Pumpkin Spice Bitch 2.5" Sticker 🙌\n #Sticker #BasicPumpkin #SpiceBitch #theacedcasino #EtsyEmail\n\n👉https://t.co/c2EpoThjrZ https://t.co/tpJw8wFvPB',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'attachments': {'media_keys': ['3_1562102533711331330',
#       '3_1562102558973657088']},
#     'id': '1562102576119947265'},
#    {'author_id': '35917386',
#     'text': 'Red Velvet is a 50 year old Scammer and Pumpkin Spice is her Scammin Ass Niece',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562102575997931520',
#     'entities': {'annotations': [{'start': 0,
#        'end': 9,
#        'probability': 0.3113,
#        'type': 'Organization',
#        'normalized_text': 'Red Velvet'}]}},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 16,
#        'username': 'evelinacloud',
#        'id': '1532452257601441792'}]},
#     'author_id': '1256623573621329925',
#     'text': 'RT @evelinacloud: i’m ready for rainy fall days &amp; pumpkin spice lattes',
#     'public_metrics': {'retweet_count': 83,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562102313384562688'},
#    {'entities': {'mentions': [{'start': 151,
#        'end': 164,
#        'username': 'dunkindonuts',
#        'id': '8771022'}],
#      'annotations': [{'start': 18,
#        'end': 30,
#        'probability': 0.6279,
#        'type': 'Product',
#        'normalized_text': 'Nutty Pumpkin'}]},
#     'author_id': '69138893',
#     'text': 'When you order a “Nutty Pumpkin” and get this.  So I’m guessing they interpreted that to 9 shots of Pumpkin spice!?  Someone got some explaining to do @dunkindonuts',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562102296250654720'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 16,
#        'username': 'evelinacloud',
#        'id': '1532452257601441792'}]},
#     'author_id': '1539415229364244482',
#     'text': 'RT @evelinacloud: i’m ready for rainy fall days &amp; pumpkin spice lattes',
#     'public_metrics': {'retweet_count': 83,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562102133465309186'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 14,
#        'username': 'buildabear',
#        'id': '14997308'}],
#      'annotations': [{'start': 92,
#        'end': 109,
#        'probability': 0.7036,
#        'type': 'Product',
#        'normalized_text': 'Pumpkin Spice Bear'}]},
#     'author_id': '1345606607829348352',
#     'text': 'RT @buildabear: It’s back in time for PSL season! Give the gift of caffeinated cuddles with Pumpkin Spice Bear! This glittery friend is pum…',
#     'public_metrics': {'retweet_count': 5,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562102106735235072'},
#    {'author_id': '855047265752203264',
#     'text': 'Pumpkin spice everything',
#     'public_metrics': {'retweet_count': 0,
#      'reply_count': 0,
#      'like_count': 0,
#      'quote_count': 0},
#     'id': '1562102081024057344'},
#    {'entities': {'mentions': [{'start': 3,
#        'end': 16,
#        'username': 'TheEmoDragon',
#        'id': '179709375'}],
#      'urls': [{'start': 98,
#        'end': 121,
#        'url': 'https://t.co/zndZDJtzX3',
#        'expanded_url': 'https://twitter.com/TheEmoDragon/status/1562094951109984259/photo/1',
#        'display_url': 'pic.twitter.com/zndZDJtzX3',
#        'media_key': '3_1562094947553234944'}],
#      'annotations': [{'start': 26,
#        'end': 45,
#        'probability': 0.5933,
#        'type': 'Product',
# ...
#     {'id': '8771022',
#      'username': 'dunkindonuts',
#      'created_at': '2007-09-09T20:21:27.000Z',
#      'public_metrics': {'followers_count': 1300403,
#       'following_count': 52102,
#       'tweet_count': 107921,
#       'listed_count': 5560},
#      'name': "Dunkin'",
#      'location': 'Canton, Mass.'},
#     {'id': '16471569',
#      'username': 'LovGloria',
#      'created_at': '2008-09-26T18:16:11.000Z',
#      'public_metrics': {'followers_count': 1319,
#       'following_count': 402,
#       'tweet_count': 154910,
#       'listed_count': 81},
#      'name': 'Gloria Holmes, MA',
#      'location': 'Ohio, USA'},
#     {'id': '857412915879710721',
#      'username': '_karly_hens',
#      'created_at': '2017-04-27T01:55:43.000Z',
#      'public_metrics': {'followers_count': 76,
#       'following_count': 518,
#       'tweet_count': 662,
#       'listed_count': 0},
#      'name': 'Karly Hensley',
#      'location': 'Oklahoma, USA'},
#     {'id': '1184619111474696198',
#      'username': 'bubblybuni',
#      'created_at': '2019-10-16T23:56:32.000Z',
#      'public_metrics': {'followers_count': 28,
#       'following_count': 313,
#       'tweet_count': 1136,
#       'listed_count': 1},
#      'name': 'Paige 🎗️🐷⚔️'},
#     {'id': '28239850',
#      'username': 'AUTrashPanda',
#      'created_at': '2009-04-02T00:43:37.000Z',
#      'public_metrics': {'followers_count': 68,
#       'following_count': 218,
#       'tweet_count': 5388,
#       'listed_count': 2},
#      'name': 'Sarah 🦝',
#      'location': 'Hartford, MI'},
#     {'id': '1253357892109033473',
#      'username': 'itsageorge',
#      'created_at': '2020-04-23T16:20:19.000Z',
#      'public_metrics': {'followers_count': 126,
#       'following_count': 327,
#       'tweet_count': 8555,
#       'listed_count': 0},
#      'name': 'g',
#      'location': 'United Kingdom'},
#     {'id': '1460802259059572737',
#      'username': 'MadamFox23',
#      'created_at': '2021-11-17T02:49:40.000Z',
#      'public_metrics': {'followers_count': 1224,
#       'following_count': 1220,
#       'tweet_count': 3515,
#       'listed_count': 8},
#      'name': 'Shaya'},
#     {'id': '596141083',
#      'username': 'kachowabunga',
#      'created_at': '2012-06-01T05:07:45.000Z',
#      'public_metrics': {'followers_count': 389,
#       'following_count': 598,
#       'tweet_count': 13812,
#       'listed_count': 1},
#      'name': 'duolingo’s biggest hater',
#      'location': 'New Orleans, LA'},
#     {'id': '1192503719021219840',
#      'username': 'AHatfieldii',
#      'created_at': '2019-11-07T18:07:28.000Z',
#      'public_metrics': {'followers_count': 631,
#       'following_count': 4994,
#       'tweet_count': 29860,
#       'listed_count': 0},
#      'name': 'Allen -- G O--B I G--B L U E',
#      'location': 'Kentucky'},
#     {'id': '951414669482348544',
#      'username': 'Da_Crimson_Fukr',
#      'created_at': '2018-01-11T11:25:08.000Z',
#      'public_metrics': {'followers_count': 29,
#       'following_count': 122,
#       'tweet_count': 3215,
#       'listed_count': 0},
#      'name': 'Manuel Acosta',
#      'location': 'United States'},
#     {'id': '1341446898645872641',
#      'username': 'JohnnyRayRich',
#      'created_at': '2020-12-22T18:14:09.000Z',
#      'public_metrics': {'followers_count': 80,
#       'following_count': 155,
#       'tweet_count': 2122,
#       'listed_count': 0},
#      'name': 'Johnny Ray',
#      'location': 'Hobbs, NM'},
#     {'id': '942851581053083648',
#      'username': 'Perlaaaaa___',
#      'created_at': '2017-12-18T20:18:29.000Z',
#      'public_metrics': {'followers_count': 56,
#       'following_count': 52,
#       'tweet_count': 860,
#       'listed_count': 0},
#      'name': 'Perla C. Encarnacion 💗',
#      'location': 'Phoenix, AZ'},
#     {'id': '1373741343613333506',
#      'username': 'Yoh_Vombis',
#      'created_at': '2021-03-21T21:01:35.000Z',
#      'public_metrics': {'followers_count': 117,
#       'following_count': 395,
#       'tweet_count': 993,
#       'listed_count': 0},
#      'name': 'John',
#      'location': 'Atlanta, GA'},
#     {'id': '122796840',
#      'username': 'scottiearealtor',
#      'created_at': '2010-03-13T23:26:11.000Z',
#      'public_metrics': {'followers_count': 301,
#       'following_count': 563,
#       'tweet_count': 711,
#       'listed_count': 10},
#      'name': 'Scottie Attaway',
#      'location': 'Houston, TX'},
#     {'id': '1919324462',
#      'username': 'annoyingnico',
#      'created_at': '2013-09-30T08:13:36.000Z',
#      'public_metrics': {'followers_count': 861,
#       'following_count': 418,
#       'tweet_count': 8532,
#       'listed_count': 0},
#      'name': 'nico',
#      'location': '♋︎ ☉ • ♌︎ ☾ • ♏︎↑'},
#     {'id': '753939205030612992',
#      'username': '911buddie',
#      'created_at': '2016-07-15T13:08:08.000Z',
#      'public_metrics': {'followers_count': 1079,
#       'following_count': 2765,
#       'tweet_count': 14197,
#       'listed_count': 5},
#      'name': 'Jamie 🇺🇸🏳️\u200d🌈',
#      'location': 'Texas, USA'},
#     {'id': '4492998268',
#      'username': 'GRStest',
#      'created_at': '2015-12-15T14:39:06.000Z',
#      'public_metrics': {'followers_count': 64,
#       'following_count': 0,
#       'tweet_count': 5284,
#       'listed_count': 0},
#      'name': 'Trading Trainer'},
#     {'id': '35917386',
#      'username': 'blu_ray381',
#      'created_at': '2009-04-28T00:11:52.000Z',
#      'public_metrics': {'followers_count': 989,
#       'following_count': 1981,
#       'tweet_count': 222036,
#       'listed_count': 35},
#      'name': 'Cardi O',
#      'location': 'CALI'},
#     {'id': '1256623573621329925',
#      'username': 'minamiua',
#      'created_at': '2020-05-02T16:36:33.000Z',
#      'public_metrics': {'followers_count': 8,
#       'following_count': 344,
#       'tweet_count': 233,
#       'listed_count': 0},
#      'name': 'miua'},
#     {'id': '69138893',
#      'username': 'RichieLarson',
#      'created_at': '2009-08-26T23:56:43.000Z',
#      'public_metrics': {'followers_count': 198,
#       'following_count': 1217,
#       'tweet_count': 4779,
#       'listed_count': 2},
#      'name': 'Raychel(Rae-chel)',
#      'location': 'Massachusetts, USA'},
#     {'id': '1539415229364244482',
#      'username': 'MySolnHisLuna',
#      'created_at': '2022-06-22T01:09:36.000Z',
#      'public_metrics': {'followers_count': 7,
#       'following_count': 4,
#       'tweet_count': 270,
#       'listed_count': 0},
#      'name': 'ֆօʟ☀️🌙⁷'},
#     {'id': '1345606607829348352',
#      'username': 'JoannUmpierre',
#      'created_at': '2021-01-03T05:43:52.000Z',
#      'public_metrics': {'followers_count': 127,
#       'following_count': 684,
#       'tweet_count': 46153,
#       'listed_count': 2},
#      'name': 'Joann Umpierre'},
#     {'id': '855047265752203264',
#      'username': 'mlizcalderon',
#      'created_at': '2017-04-20T13:15:28.000Z',
#      'public_metrics': {'followers_count': 247,
#       'following_count': 274,
#       'tweet_count': 4398,
#       'listed_count': 0},
#      'name': 'Liz Calderón'},
#     {'id': '92865488',
#      'username': 'ronaldcworld',
#      'created_at': '2009-11-27T00:14:56.000Z',
#      'public_metrics': {'followers_count': 458,
#       'following_count': 963,
#       'tweet_count': 7382,
#       'listed_count': 6},
#      'name': 'Clueless Ron (Top Secrets arc)',
#      'location': 'Spring, TX '},
#     {'id': '1323686329855565824',
#      'username': 'alison1derbean',
#      'created_at': '2020-11-03T18:00:38.000Z',
#      'public_metrics': {'followers_count': 9,
#       'following_count': 37,
#       'tweet_count': 6338,
#       'listed_count': 0},
#      'name': "Schrödinger's Café au Lait"},
#     {'id': '31197164',
#      'username': 'lauraleannee',
#      'created_at': '2009-04-14T19:06:14.000Z',
#      'public_metrics': {'followers_count': 10964,
#       'following_count': 201,
#       'tweet_count': 171265,
#       'listed_count': 240},
#      'name': 'laura'},
#     {'id': '1236320238599376896',
#      'username': 'robinsahoyhat',
#      'created_at': '2020-03-07T15:58:49.000Z',
#      'public_metrics': {'followers_count': 677,
#       'following_count': 1415,
#       'tweet_count': 11780,
#       'listed_count': 13},
#      'name': 'arsonic 🔪 is watching a league of their own',
#      'location': 'he/void/nor/wy/wires 🖐// 17'},
#     {'id': '1278089777871544330',
#      'username': 'LakeyTheDolphin',
#      'created_at': '2020-06-30T22:15:31.000Z',
#      'public_metrics': {'followers_count': 264,
#       'following_count': 1452,
#       'tweet_count': 14553,
#       'listed_count': 0},
#      'name': 'Lakey | approaching spooky time 🧡🖤🎃',
#      'location': 'NAFO Conference'},
#     {'id': '251439365',
#      'username': 'UWANAwhaa0_o',
#      'created_at': '2011-02-13T04:08:32.000Z',
#      'public_metrics': {'followers_count': 814,
#       'following_count': 808,
#       'tweet_count': 51215,
#       'listed_count': 8},
#      'name': 'Unhinged Elmo Energy 👹🥊⚡️',
#      'location': 'Where the money Reside'},
#     {'id': '3002559651',
#      'username': 'belbenitezg',
#      'created_at': '2015-01-28T03:38:02.000Z',
#      'public_metrics': {'followers_count': 83,
#       'following_count': 76,
#       'tweet_count': 5905,
#       'listed_count': 1},
#      'name': 'Ana Isabel',
#      'location': 'North Carolina, USA'},
#     {'id': '42482580',
#      'username': 'gwo4',
#      'created_at': '2009-05-25T20:41:04.000Z',
#      'public_metrics': {'followers_count': 2108,
#       'following_count': 3822,
#       'tweet_count': 44839,
#       'listed_count': 55},
#      'name': 'Scott Watts',
#      'location': 'Nicholasville Ky.'},
#     {'id': '1607226949',
#      'username': 'fem_wrstlng_fan',
#      'created_at': '2013-07-20T02:05:46.000Z',
#      'public_metrics': {'followers_count': 197,
#       'following_count': 135,
#       'tweet_count': 85347,
#       'listed_count': 6},
#      'name': 'Philip'},
#     {'id': '1321771198720729088',
#      'username': 'hausofmyk',
#      'created_at': '2020-10-29T11:10:00.000Z',
#      'public_metrics': {'followers_count': 23,
#       'following_count': 231,
#       'tweet_count': 269,
#       'listed_count': 0},
#      'name': 'big myk.'},
#     {'id': '1528449944104886274',
#      'username': 'Joshuahiggins93',
#      'created_at': '2022-05-22T18:57:32.000Z',
#      'public_metrics': {'followers_count': 23,
#       'following_count': 208,
#       'tweet_count': 87,
#       'listed_count': 0},
#      'name': 'Joshua Higgins',
#      'location': 'Kentucky, USA'},
#     {'id': '510150129',
#      'username': 'holysheats',
#      'created_at': '2012-03-01T12:17:38.000Z',
#      'public_metrics': {'followers_count': 123,
#       'following_count': 299,
#       'tweet_count': 13343,
#       'listed_count': 2},
#      'name': 'allison chains',
#      'location': 'back of the club sippin Moët '},
#     {'id': '1129880223866949632',
#      'username': 'Glauscon',
#      'created_at': '2019-05-18T22:43:32.000Z',
#      'public_metrics': {'followers_count': 5,
#       'following_count': 402,
#       'tweet_count': 1865,
#       'listed_count': 0},
#      'name': 'Glauscon'},
#     {'id': '818649290406903808',
#      'username': 'erikaajaclyn',
#      'created_at': '2017-01-10T02:42:55.000Z',
#      'public_metrics': {'followers_count': 139,
#       'following_count': 120,
#       'tweet_count': 3719,
#       'listed_count': 0},
#      'name': 'e'},
#     {'id': '1121835684849958914',
#      'username': 'AbozzP',
#      'created_at': '2019-04-26T17:57:24.000Z',
#      'public_metrics': {'followers_count': 2182,
#       'following_count': 3366,
#       'tweet_count': 6680,
#       'listed_count': 6},
#      'name': 'Alessandro Bozzo - aBozz Productions',
#      'location': 'Toronto, Ontario'},
#     {'id': '1143932900',
#      'username': 'WhitneyJayWhite',
#      'created_at': '2013-02-03T01:56:53.000Z',
#      'public_metrics': {'followers_count': 380,
#       'following_count': 422,
#       'tweet_count': 3577,
#       'listed_count': 0},
#      'name': 'Dark Skin Aunt Viv 🇩🇲',
#      'location': 'Dominica'},
#     {'id': '1104545791916544000',
#      'username': 'yourstruly_mar',
#      'created_at': '2019-03-10T00:53:33.000Z',
#      'public_metrics': {'followers_count': 332,
#       'following_count': 392,
#       'tweet_count': 3776,
#       'listed_count': 0},
#      'name': 'mar mar 🥳💜',
#      'location': 'Tampa, FL'},
#     {'id': '1255404071848206339',
#      'username': 'parislikespears',
#      'created_at': '2020-04-29T07:52:23.000Z',
#      'public_metrics': {'followers_count': 36,
#       'following_count': 200,
#       'tweet_count': 2467,
#       'listed_count': 0},
#      'name': '𝙿 𝚊 𝚛 𝚒 𝚜🗼',
#      'location': 'Somewhere other than reality'},
#     {'id': '776623046',
#      'username': 'CatalinaG04',
#      'created_at': '2012-08-23T19:40:44.000Z',
#      'public_metrics': {'followers_count': 573,
#       'following_count': 471,
#       'tweet_count': 4772,
#       'listed_count': 0},
#      'name': 'Catalina 💞'},
#     {'id': '15362786',
#      'username': 'MusingsofaMuse',
#      'created_at': '2008-07-09T05:55:56.000Z',
#      'public_metrics': {'followers_count': 16504,
#       'following_count': 269,
#       'tweet_count': 71878,
#       'listed_count': 386},
#      'name': 'Musings of a Muse',
#      'location': 'New York'},
#     {'id': '1556656092813328384',
#      'username': 'ananingz',
#      'created_at': '2022-08-08T14:59:21.000Z',
#      'public_metrics': {'followers_count': 141,
#       'following_count': 166,
#       'tweet_count': 247,
#       'listed_count': 0},
#      'name': 'nana ˖⋆',
#      'location': 'she, edtwt, byf ➛'},
#     {'id': '1113519010874843136',
#      'username': 'trishtheartist',
#      'created_at': '2019-04-03T19:09:55.000Z',
#      'public_metrics': {'followers_count': 7737,
#       'following_count': 974,
#       'tweet_count': 76463,
#       'listed_count': 75},
#      'name': 'trish the artist 𓍊𓋼',
#      'location': 'Connecticut '},
#     {'id': '1189147477464608768',
#      'username': 'greasy0deer',
#      'created_at': '2019-10-29T11:50:42.000Z',
#      'public_metrics': {'followers_count': 194,
#       'following_count': 376,
#       'tweet_count': 1726,
#       'listed_count': 2},
#      'name': 'SONAR'},
#     {'id': '557316458',
#      'username': 'dmonneeeyyy',
#      'created_at': '2012-04-18T23:49:59.000Z',
#      'public_metrics': {'followers_count': 513,
#       'following_count': 272,
#       'tweet_count': 27374,
#       'listed_count': 1},
#      'name': 'dмoɴey',
#      'location': 'MakingMoneyMindingMyBusiness  '},
#     {'id': '19999391',
#      'username': 'hitzdrummergurl',
#      'created_at': '2009-02-03T20:08:18.000Z',
#      'public_metrics': {'followers_count': 2573,
#       'following_count': 5000,
#       'tweet_count': 43733,
#       'listed_count': 35},
#      'name': 'Christa Sunderland',
#      'location': 'Richmond, VA'}],
#    'media': [{'media_key': '3_1561781778058289154', 'type': 'photo'},
#     {'media_key': '16_1562106565167030273', 'type': 'animated_gif'},
#     {'media_key': '7_1162954272918646784',
#      'public_metrics': {'view_count': 488597},
#      'type': 'video'},
#     {'media_key': '3_1562105651064705024', 'type': 'photo'},
#     {'media_key': '3_1562105657205170177', 'type': 'photo'},
#     {'media_key': '7_1562103969651970055',
#      'public_metrics': {'view_count': 228},
#      'type': 'video'},
#     {'media_key': '7_1561498793077530625',
#      'public_metrics': {'view_count': 41237},
#      'type': 'video'},
#     {'media_key': '7_1561104980844728320',
#      'public_metrics': {'view_count': 242391},
#      'type': 'video'},
#     {'media_key': '16_1562103825988812802', 'type': 'animated_gif'},
#     {'media_key': '13_1560658709692690432',
#      'public_metrics': {'view_count': 13513},
#      'type': 'video'},
#     {'media_key': '7_1499870788622688263',
#      'public_metrics': {'view_count': 238648},
#      'type': 'video'},
#     {'media_key': '3_1562102533711331330', 'type': 'photo'},
#     {'media_key': '3_1562102558973657088', 'type': 'photo'},
#     {'media_key': '3_1562094947553234944', 'type': 'photo'},
#     {'media_key': '3_1562101633999405060', 'type': 'photo'},
#     {'media_key': '3_1562101639758094340', 'type': 'photo'},
#     {'media_key': '3_1561798011881136133', 'type': 'photo'},
#     {'media_key': '3_1562100817506832384', 'type': 'photo'},
#     {'media_key': '3_1562100821076180992', 'type': 'photo'},
#     {'media_key': '3_1562094021064933376', 'type': 'photo'}]},
#   'meta': {'newest_id': '1562107241460891649',
#    'oldest_id': '1562100508193689603',
#    'result_count': 99,
#    'next_token': 'b26v89c19zqg8o3fpz8kqbsdfo9akt7abouzwbxrrquf1'}}]
